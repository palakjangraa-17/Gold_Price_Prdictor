# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("GoldUSD.csv")

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.round(1)
# Out:
#           Date    Open    High     Low   Close  Volume
# 0     30-08-00   273.9   273.9   273.9   273.9       0
# 1     31-08-00   274.8   278.3   274.8   278.3       0
# 2     01-09-00   277.0   277.0   277.0   277.0       0
# 3     05-09-00   275.8   275.8   275.8   275.8       2
# 4     06-09-00   274.2   274.2   274.2   274.2       0
# ...        ...     ...     ...     ...     ...     ...
# 6394  25-02-26  5166.0  5206.4  5166.0  5206.4    1772
# 6395  26-02-26  5177.2  5199.2  5143.9  5176.5    1520
# 6396  27-02-26  5186.7  5280.0  5176.7  5230.5     354
# 6397  02-03-26  5346.6  5405.0  5266.3  5294.4     354
# 6398  03-03-26  5335.7  5394.2  5334.9  5377.3   21189
#
# [6399 rows x 6 columns]

# %%
p=df.drop(columns=["Date"])

# %%
p.round(1)
# Out:
#         Open    High     Low   Close  Volume
# 0      273.9   273.9   273.9   273.9       0
# 1      274.8   278.3   274.8   278.3       0
# 2      277.0   277.0   277.0   277.0       0
# 3      275.8   275.8   275.8   275.8       2
# 4      274.2   274.2   274.2   274.2       0
# ...      ...     ...     ...     ...     ...
# 6394  5166.0  5206.4  5166.0  5206.4    1772
# 6395  5177.2  5199.2  5143.9  5176.5    1520
# 6396  5186.7  5280.0  5176.7  5230.5     354
# 6397  5346.6  5405.0  5266.3  5294.4     354
# 6398  5335.7  5394.2  5334.9  5377.3   21189
#
# [6399 rows x 5 columns]

# %%
y=p[["Close"]]
x=p[["Open","High","Low"]]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Palak\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[1210.33857877],
#        [2655.90008056],
#        [1634.69785169],
#        ...,
#        [ 375.06533615],
#        [ 682.18576978],
#        [2356.58573659]], shape=(1280, 1))

# %%
y_test
# Out:
#             Close
# 4498  1211.099976
# 6050  2657.600098
# 4890  1641.099976
# 4527  1196.199951
# 132    266.799988
# ...           ...
# 4087  1131.500000
# 1726   672.500000
# 748    373.200012
# 1662   681.799988
# 5955  2355.199951
#
# [1280 rows x 1 columns]

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.99993779883561

# %%
import joblib
import pickle
joblib.dump(lr,"Linear_Regression_Batch_2.pkl")
# Out:
# ['Linear_Regression_Batch_2.pkl']
